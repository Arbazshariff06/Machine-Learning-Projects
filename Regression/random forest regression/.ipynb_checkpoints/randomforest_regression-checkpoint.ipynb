# %% [markdown]
# # 🌾 Crop Yield Prediction using Random Forest Regressor

# %% [markdown]
# ## ---- Import Necessary Libraries ----

# %%
import pandas as pd  # For data manipulation and analysis
import numpy as np   # For numerical computations
import matplotlib.pyplot as plt  # For visualization
import seaborn as sns  # For advanced plots

# %% [markdown]
# ## ---- Load the Dataset ----

# %%
dataset = pd.read_csv('crop_yield.csv')
dataset.head()
# Out:
#   Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0   West     Sandy   Cotton   897.077239            27.676966
# 1  South      Clay     Rice   992.673282            18.026142
# 2  North      Loam   Barley   147.998025            29.794042
# 3  North     Sandy  Soybean   986.866331            16.644190
# 4  South      Silt    Wheat   730.379174            31.620687
#
#    Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0            False             True            Cloudy              122
# 1             True             True             Rainy              140
# 2            False            False             Sunny              106
# 3            False             True             Rainy              146
# 4             True             True            Cloudy              110
#
#    Yield_tons_per_hectare
# 0                6.555816
# 1                8.527341
# 2                1.127443
# 3                6.517573
# 4                7.248251

# %%
# Display first few rows
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   Region                  1000000 non-null  object
#  1   Soil_Type               1000000 non-null  object
#  2   Crop                    1000000 non-null  object
#  3   Rainfall_mm             1000000 non-null  float64
#  4   Temperature_Celsius     1000000 non-null  float64
#  5   Fertilizer_Used         1000000 non-null  bool
#  6   Irrigation_Used         1000000 non-null  bool
#  7   Weather_Condition       1000000 non-null  object
#  8   Days_to_Harvest         1000000 non-null  int64
#  9   Yield_tons_per_hectare  1000000 non-null  float64
# dtypes: bool(2), float64(3), int64(1), object(4)
# memory usage: 62.9+ MB

# %%
# Show statistical summary of numerical columns
dataset.describe()
# Out:
#           Rainfall_mm  Temperature_Celsius  Days_to_Harvest  \
# count  1000000.000000       1000000.000000   1000000.000000
# mean       549.981901            27.504965       104.495025
# std        259.851320             7.220608        25.953412
# min        100.000896            15.000034        60.000000
# 25%        324.891090            21.254502        82.000000
# 50%        550.124061            27.507365       104.000000
# 75%        774.738520            33.753267       127.000000
# max        999.998098            39.999997       149.000000
#
#        Yield_tons_per_hectare
# count          1000000.000000
# mean                 4.649472
# std                  1.696572
# min                 -1.147613
# 25%                  3.417637
# 50%                  4.651808
# 75%                  5.879200
# max                  9.963372

# %%
# Check for missing values in each column
dataset.isnull().sum()
# Out:
# Region                    0
# Soil_Type                 0
# Crop                      0
# Rainfall_mm               0
# Temperature_Celsius       0
# Fertilizer_Used           0
# Irrigation_Used           0
# Weather_Condition         0
# Days_to_Harvest           0
# Yield_tons_per_hectare    0
# dtype: int64

# %% [markdown]
# # ---- Encode Categorical Variables ----

# %%
from sklearn.preprocessing import LabelEncoder
# Encode categorical columns into numeric values
lb = LabelEncoder()
for col in ["Region", "Soil_Type","Crop", "Weather_Condition"]:
    dataset[col] = lb.fit_transform(dataset[col])

# %% [markdown]
# ## ---- Visualization Section ----

# %%
# --- Distribution of Target Variable ---
plt.figure(figsize=(8,5))
sns.histplot(dataset['Yield_tons_per_hectare'], kde=True, bins=30)
plt.title("Distribution of Crop Yield")
plt.xlabel("Yield (tons/ha)")
plt.ylabel("Frequency")
plt.show()

# %%
# --- Correlation Analysis (Numerical Features) ---
numeric_cols = ['Rainfall_mm', 'Temperature_Celsius', 'Days_to_Harvest', 'Yield_tons_per_hectare']
plt.figure(figsize=(8,6))
sns.heatmap(dataset[numeric_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# --- Countplots for Categorical Features ---
categorical_cols = ['Region', 'Soil_Type', 'Crop', 'Weather_Condition', 'Fertilizer_Used', 'Irrigation_Used']
for col in categorical_cols:
    plt.figure(figsize=(8,4))
    sns.countplot(data=dataset, x=col)
    plt.title(f"Count of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
# --- Boxplots to Check Impact on Yield ---
for col in categorical_cols:
    plt.figure(figsize=(8,5))
    sns.boxplot(x=col, y='Yield_tons_per_hectare', data=dataset)
    plt.title(f"Yield by {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
# --- Pairplot for Numerical Features ---
sns.pairplot(dataset[numeric_cols])
plt.show()

# %%
# --- Identify Outliers ---
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(y=dataset[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
# ---- Correlation with Target Variable ----
dataset.corr()["Yield_tons_per_hectare"]
# Out:
# Region                    0.000390
# Soil_Type                -0.000333
# Crop                      0.001283
# Rainfall_mm               0.764618
# Temperature_Celsius       0.085565
# Fertilizer_Used           0.442099
# Irrigation_Used           0.353741
# Weather_Condition         0.001132
# Days_to_Harvest          -0.002591
# Yield_tons_per_hectare    1.000000
# Name: Yield_tons_per_hectare, dtype: float64

# %% [markdown]
# # ---- Prepare Data for Modeling ----

# %%
X = dataset.drop(["Yield_tons_per_hectare"], axis = 1)
y = dataset["Yield_tons_per_hectare"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# ## ---- Split Data into Training and Testing Sets ----

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 42)
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=42)

# %%
# ---- Predict on Test Data ----
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([3.93029487, 4.53761854, 6.90935725, ..., 5.41472026, 2.75878457,
#        3.30405679])

# %%
# Reset index of X_test and y_test to align properly
X_test_reset = X_test.reset_index(drop=True)
y_test_reset = y_test.reset_index(drop=True)

# Create a comparison DataFrame with all features + actual + predicted
comparison_all = X_test_reset.copy()  # Start with features
comparison_all['Actual_Yield'] = y_test_reset  # Add actual target
comparison_all['Predicted_Yield'] = y_pred     # Add predicted target

# Display the first 20 rows
print(comparison_all.head(20))
# Out:
#     Region  Soil_Type  Crop  Rainfall_mm  Temperature_Celsius  \
# 0        3          5     1   714.854403            23.875872
# 1        1          0     1   860.604672            23.070897
# 2        1          4     0   802.081954            24.020125
# 3        3          0     1   203.616909            16.895211
# 4        0          5     3   510.528102            18.402903
# 5        3          1     3   932.718558            32.815770
# 6        3          1     1   668.894472            30.558030
# 7        3          2     4   568.575579            31.835166
# 8        2          3     1   946.278946            21.077978
# 9        2          3     4   406.883536            28.813306
# 10       0          0     1   829.939117            39.619143
# 11       0          2     4   903.847002            24.377116
# 12       1          1     2   551.970026            29.248393
# 13       3          0     4   382.395071            32.559689
# 14       0          1     4   598.494092            32.172378
# 15       0          1     5   578.830783            33.320849
# 16       0          2     2   985.774503            17.676845
# 17       1          2     2   565.929778            16.933047
# 18       2          0     3   856.073201            24.784856
# 19       2          3     4   296.769190            39.287596
#
#     Fertilizer_Used  Irrigation_Used  Weather_Condition  Days_to_Harvest  \
# 0             False            False                  2              120
# 1             False            False                  1               78
# 2              True             True                  1              140
# 3             False             True                  2               96
# 4             False             True                  0               65
# 5              True            False                  2               89
# 6              True             True                  0              147
# 7              True             True                  1               98
# 8              True             True                  2              103
# 9             False             True                  1              137
# 10             True            False                  0               72
# 11             True             True                  1               85
# 12            False            False                  1              119
# 13            False            False                  2              116
# 14             True            False                  2               61
# 15            False            False                  1              142
# 16             True            False                  2               95
# 17             True            False                  1               78
# 18            False             True                  2              113
# 19             True             True                  1              145
#
#     Actual_Yield  Predicted_Yield
# 0       3.840988         3.930295
# 1       5.138173         4.537619
# 2       6.401523         6.909357
# 3       2.658805         2.546117
# 4       2.797703         4.035873
# 5       7.691631         6.861967
# 6       6.338488         6.714560
# 7       5.495826         6.078732
# 8       9.076388         7.879874
# 9       3.970273         3.913426
# 10      5.834142         6.329859
# 11      7.379368         7.847129
# 12      3.792982         2.948342
# 13      1.987434         2.365006
# 14      4.681317         5.293376
# 15      3.659098         3.304736
# 16      6.641805         6.879316
# 17      4.574283         4.488858
# 18      5.656460         6.176294
# 19      4.768863         4.787600

# %%
# Simple comparison DataFrame (Actual vs Predicted only)
comparison = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
comparison
# Out:
#           Actual  Predicted
# 987231  3.840988   3.930295
# 79954   5.138173   4.537619
# 567130  6.401523   6.909357
# 500891  2.658805   2.546117
# 55399   2.797703   4.035873
# ...          ...        ...
# 463299  3.504765   3.630940
# 728324  6.891932   6.790504
# 76260   4.996468   5.414720
# 77813   2.252224   2.758785
# 718205  2.925302   3.304057
#
# [300000 rows x 2 columns]

# %%
# Calculate evaluation metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f"R² Score: {r2:.3f}")
print(f"Mean Absolute Error: {mae:.3f}")
print(f"Mean Squared Error: {mse:.3f}")
# Out:
# R² Score: 0.899
# Mean Absolute Error: 0.431
# Mean Squared Error: 0.291

# %%
# --- Plot Actual vs Predicted ---
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, alpha=0.7, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # perfect prediction line
plt.xlabel("Actual Yield (tons/ha)")
plt.ylabel("Predicted Yield (tons/ha)")
plt.title("Random Forest Regression: Actual vs Predicted Yield")
plt.show()
